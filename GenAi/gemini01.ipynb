# %%
! pip install google-genai
#pulling from Pypi because it has been published there
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.2/818.2 kB 2.7 MB/s  0:00:0036m-:--:--
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [google-genai] [google-genai]
# ...

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/bin/python3

# %%
import sys
# !{sys.executable} -m pip install -U google-genai
# Out:
# ...
#   Using cached google_genai-2.4.0-py3-none-any.whl.metadata (52 kB)
# ...
#   Using cached google_auth-2.53.0-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# ...
# Using cached google_genai-2.4.0-py3-none-any.whl (818 kB)
# Using cached google_auth-2.53.0-py3-none-any.whl (246 kB)
# ...
# Using cached websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl (175 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 2.8 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
! pip install google-genai
! pip install -U google-genai
from google import genai
client = genai.Client(api_key="AIzaSyBMwtinq_Sraji5TSVcbBvUd2kW4O3CtPQ")
response = client.responses.create(
    model="gemini-2.5-flash",
    input="Explain how AI works in few words"
)
print(response.output_text)
#print(respose.text)
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 5
#       1 get_ipython().system(' pip install google-genai')
#       2 get_ipython().system(' pip install -U google-genai')
#       3 from google import genai
#       4 client = genai.Client(api_key="AIzaSyBMwtinq_Sraji5TSVcbBvUd2kW4O3CtPQ")
# ----> 5 response = client.responses.create(
#       6     model="gemini-2.5-flash",
#       7     input="Explain how AI works in few words"
#       8 )
#
# AttributeError: 'Client' object has no attribute 'responses'
