# %%
"""
def outer(func):
def inner():
print("Before")
func()
print("After")
            "source": [
                "# API key removed for security. Do NOT commit keys into notebooks.",
                "# Set your API key in the OPENAI_API_KEY environment variable before running.",
                "# Example (macOS / Linux): export OPENAI_API_KEY=\"sk-...\""
            ]
def hello():
            "source": [
                "%pip install openai",
                "import os",
                "from openai import OpenAI",
                "api_key = os.environ.get('OPENAI_API_KEY')",
                "if not api_key:",
                "    raise RuntimeError('Set the OPENAI_API_KEY environment variable before running.')",
                "client = OpenAI(api_key=api_key)",
                "import time, random",
                "def call_with_retry(func, max_retries=6):",
                "    for attempt in range(max_retries):",
                "        try:",
                "            return func()",
                "        except Exception as e:",
                "            # Retry on 429-like errors with exponential backoff + jitter",
                "            wait = (2 ** attempt) + random.uniform(0, 0.5)",
                "            time.sleep(wait)",
                "    raise RuntimeError('Max retries exceeded')",
                "",
                "response = call_with_retry(lambda: client.completions.create(",
                "    model='gpt-3.5-turbo-instruct',",
                "    prompt='Hello, how are you?',",
                "    max_tokens=5",
                "))",
                "print(response.choices[0].text.strip())"
            ]
D. A static reference

"""

# %%
#Outptut: B. The object instance

# %%
"""
3. Which inheritance type is shown below?
class A:
pass
class B(A):
pass
class C(A):
pass

"""

# %%
#Output: Hierarchical Inheritance

# %%
"""
4. What is the output?

class A:
def __init__(self):
print("A constructor")
class B(A):
pass
obj = B()

"""

# %%
#Output:Nothing will be printed because the constructor of class A is not called when creating an instance of class B.

# %%
"""
5. What does super() do?
A. Calls parent class methods
B. Creates new objects
C. Deletes objects
D. Makes method private

"""

# %%
#output: A. Calls parent class methods

# %%
"""
6. Which method is automatically called when an object is created?
A. __str__()
B. __init__()
C. __call__()
D. __del__()

"""

# %%
#Output: __init__()

# %%
"""
7. What is the output?
class A:
def show(self):
print(&quot;A&quot;)
class B(A):
def show(self):
print(&quot;B&quot;)
obj = B()
obj.show()
"""

# %%
#output: B. Calls parent class methods

# %%
"""
8. Which symbol represents a protected member?
A. __var
B. _var
C. var_
D. var__
"""

# %%
#Output: B. _var

# %%
"""
9. What does yield return?
A. A list
B. A generator object
C. A tuple
D. A dictionary
"""

# %%
#output: B. A generator object

# %%
"""
10. What is the purpose of __iter__()?
A. Start iteration
B. Stop iteration
C. Delete object
D. Create class
"""

# %%
#Output: start iteration

# %%
"""
11. What is the output?
class Test:
def __init__(self):
print("Constructor")
t = Test()
"""

# %%
#Output:Constructor

# %%
"""
12. Identify the inheritance type.
class A:
pass
class B(A):
pass

class C(B):
pass
"""

# %%
#Output: Multilevel Inheritance

# %%
"""
13. What is the output?
class Parent:
def show(self):
print("Parent")
class Child(Parent):
pass
c = Child()
c.show()
"""

# %%
#output: Parent
