# %%
list1=[]
dict1={}
for i in range(5):
    key = "key"+str(i)
    dict1[key] = i
    list1.append(dict1)
print(list1)
# Out:
# [{'key0': 0, 'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}, {'key0': 0, 'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}, {'key0': 0, 'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}, {'key0': 0, 'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}, {'key0': 0, 'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}]

# %%
def multiply(a, b):
    """Multiplies the value of a and b"""
    return a*b


# Print the docstring of multiply function

print(multiply.__doc__)
multiply(2, 3)
# Out:
# Multiplies the value of a and b
# 6

# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
integer_list=[1,2,3,4,5]
print(integer_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
integer_list.append(6)

# %%
integer_list
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
integer_list[0]
# Out:
# 1

# %%
integer_list[-1]
# Out:
# 6

# %%
#list slicing
#integer_list[start:stop:step]
integer_list[1:4:1]
# Out:
# [2, 3, 4]

# %%
list(filter(lambda x: x>5,[1,2,3,4,5,6,7,8,8,9,10]))
# Out:
# [6, 7, 8, 8, 9, 10]
