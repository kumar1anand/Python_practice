# %%
my_tuple = ()

# %%
print(type(my_tuple))
# Out:
# <class 'tuple'>

# %%
print((my_tuple))
# Out:
# ()

# %%
my_tuple = (1, 2, 3,"anand")

# %%
print(my_tuple)
# Out:
# (1, 2, 3, 'anand')

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/anandkumar/Documents/pythonProgramming/00Variables
